# %%
import requests
import re
from urllib.parse import urljoin
import gzip
import shutil

# URL of the page containing the download links
#url = 'https://zenodo.org/record/1808741'
url = 'https://archive.org/details/archiveteam-twitter-stream-2022-10'

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.text

# Search for the download links in the HTML content
download_links = re.findall(r'<a class="stealth download-pill" href="([^"]+)"', html_content)

# Convert the relative URLs to absolute URLs
base_url = 'https://archive.org/'
download_links = [urljoin(base_url, link) for link in download_links]
#Test with 2 files
#download_links = download_links[17:]

# Download the files
for link in download_links:
    response = requests.get(link)
    filename = link.split('/')[-1]
    with open(filename, 'wb') as f:
        f.write(response.content)
        print(f'{filename} downloaded successfully')
        # Open the compressed file
        #with gzip.open(filename, 'rb') as f_in:
         #   # Create the extracted file
         #   with open(filename, 'wb') as f_out:
                # Copy the contents of the compressed file to the extracted file
          #      shutil.copyfileobj(f_in, f_out)

        print(f'{filename} extracted successfully')
# Out:
# twitter-stream-20221001.tar downloaded successfully
# twitter-stream-20221001.tar extracted successfully
# twitter-stream-20221002.tar downloaded successfully
# twitter-stream-20221002.tar extracted successfully
# twitter-stream-20221003.tar downloaded successfully
# twitter-stream-20221003.tar extracted successfully
# twitter-stream-20221004.tar downloaded successfully
# twitter-stream-20221004.tar extracted successfully
# twitter-stream-20221005.tar downloaded successfully
# twitter-stream-20221005.tar extracted successfully
# twitter-stream-20221006.tar downloaded successfully
# twitter-stream-20221006.tar extracted successfully
# twitter-stream-20221007.tar downloaded successfully
# twitter-stream-20221007.tar extracted successfully
# twitter-stream-20221008.tar downloaded successfully
# twitter-stream-20221008.tar extracted successfully
# twitter-stream-20221009.tar downloaded successfully
# twitter-stream-20221009.tar extracted successfully
# twitter-stream-20221010.tar downloaded successfully
# twitter-stream-20221010.tar extracted successfully
# twitter-stream-20221011.tar downloaded successfully
# twitter-stream-20221011.tar extracted successfully
# twitter-stream-20221012.tar downloaded successfully
# twitter-stream-20221012.tar extracted successfully
# twitter-stream-20221013.tar downloaded successfully
# twitter-stream-20221013.tar extracted successfully
# twitter-stream-20221014.tar downloaded successfully
# twitter-stream-20221014.tar extracted successfully
# twitter-stream-20221015.tar downloaded successfully
# twitter-stream-20221015.tar extracted successfully
# twitter-stream-20221016.tar downloaded successfully
# twitter-stream-20221016.tar extracted successfully
# twitter-stream-20221017.tar downloaded successfully
# twitter-stream-20221017.tar extracted successfully
# twitter-stream-20221018.tar downloaded successfully
# twitter-stream-20221018.tar extracted successfully
# twitter-stream-20221019.tar downloaded successfully
# twitter-stream-20221019.tar extracted successfully
# twitter-stream-20221020.tar downloaded successfully
# twitter-stream-20221020.tar extracted successfully
# twitter-stream-20221021.tar downloaded successfully
# twitter-stream-20221021.tar extracted successfully
# twitter-stream-20221022.tar downloaded successfully
# twitter-stream-20221022.tar extracted successfully
# twitter-stream-20221023.tar downloaded successfully
# twitter-stream-20221023.tar extracted successfully
# twitter-stream-20221024.tar downloaded successfully
# twitter-stream-20221024.tar extracted successfully
# twitter-stream-20221025.tar downloaded successfully
# twitter-stream-20221025.tar extracted successfully
# twitter-stream-20221026.tar downloaded successfully
# twitter-stream-20221026.tar extracted successfully
# twitter-stream-20221027.tar downloaded successfully
# twitter-stream-20221027.tar extracted successfully
# twitter-stream-20221028.tar downloaded successfully
# twitter-stream-20221028.tar extracted successfully
# twitter-stream-20221029.tar downloaded successfully
# twitter-stream-20221029.tar extracted successfully
# twitter-stream-20221030.tar downloaded successfully
# twitter-stream-20221030.tar extracted successfully
# twitter-stream-20221031.tar downloaded successfully
# twitter-stream-20221031.tar extracted successfully
